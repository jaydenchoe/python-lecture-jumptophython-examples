# %%
# !pip install streamlit

# %%
# %%writefile app.py
import streamlit as st
st.title("테스트")
st.write("콜랩에서도 스트림릿 실행됨")

# %%
# !streamlit run app.py &>/dev/null&

# %%
from google.colab.output import eval_js
eval_js("google.colab.kernel.proxyPort(8501)")
